# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
f = r'C:\Users\Josè Valencia\Desktop\Predictive Modelling Actuarial Applications\Volume 2\Chapter 1 - Pure Premium Modeling\sim-modeling-dataset.csv'
data = pd.read_csv(f, low_memory=False, index_col=0)
data.head()
# Out:
#         year  exposure nb.rb  driver.age  drv.age driver.gender  \
# row.id
# 1       2010  1.000000    RB          63       63          Male
# 2       2010  1.000000    NB          33       33          Male
# 3       2010  1.000000    RB          68       68          Male
# 4       2010  0.083333    RB          68       68          Male
# 5       2010  1.000000    RB          68       68          Male
#
#        marital.status  yrs.licensed yrs.lic  ncd.level  ...   ccm  hp  weight  \
# row.id                                                  ...
# 1             Married             5       5          6  ...  1248  70    1285
# 2             Married             1       1          5  ...  2476  94    1670
# 3             Married             2       2          4  ...  1948  90    1760
# 4             Married             2       2          4  ...  1948  90    1760
# 5             Married             2       2          3  ...  1461  85    1130
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40760 entries, 1 to 40760
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            40760 non-null  int64
#  1   exposure        40760 non-null  float64
#  2   nb.rb           40760 non-null  object
#  3   driver.age      40760 non-null  int64
#  4   drv.age         40760 non-null  int64
#  5   driver.gender   40760 non-null  object
#  6   marital.status  40760 non-null  object
#  7   yrs.licensed    40760 non-null  int64
#  8   yrs.lic         40760 non-null  object
#  9   ncd.level       40760 non-null  int64
#  10  region          40760 non-null  int64
#  11  body.code       40760 non-null  object
#  12  vehicle.age     40760 non-null  int64
#  13  veh.age         40760 non-null  int64
#  14  vehicle.value   40760 non-null  float64
#  15  seats           40760 non-null  int64
#  16  ccm             40760 non-null  int64
# ...

# %% [markdown]
# ### EDA for Frecuency

# %%
data.pivot_table(index='year', columns='nb.rb', values='clm.count', aggfunc='count')
# Out:
# nb.rb    NB    RB
# year
# 2010   4790  2348
# 2011   6676  3468
# 2012   8519  4333
# 2013   7359  3267

# %%
197+67
# Out:
# 264

# %%
data2 = data.groupby(['nb.rb', 'clm.count'])

# %%
data['yrs.lic'].value_counts()
# Out:
# 2     9022
# 1     8870
# 3     7119
# 4     5574
# 5     4493
# 6     3112
# 7     1774
# 8      685
# 9      110
# 9+       1
# Name: yrs.lic, dtype: int64
